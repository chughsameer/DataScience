# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bitcoin_data = pd.read_csv("Dataset\coin_Bitcoin.csv")
ethereum_data = pd.read_csv("Dataset\coin_Ethereum.csv")
dogecoin_data = pd.read_csv("Dataset\coin_Dogecoin.csv")

# %%
bitcoin_data.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
ethereum_data.head()
# Out:
#    SNo      Name Symbol                 Date      High       Low      Open  \
# 0    1  Ethereum    ETH  2015-08-08 23:59:59  2.798810  0.714725  2.793760
# 1    2  Ethereum    ETH  2015-08-09 23:59:59  0.879810  0.629191  0.706136
# 2    3  Ethereum    ETH  2015-08-10 23:59:59  0.729854  0.636546  0.713989
# 3    4  Ethereum    ETH  2015-08-11 23:59:59  1.131410  0.663235  0.708087
# 4    5  Ethereum    ETH  2015-08-12 23:59:59  1.289940  0.883608  1.058750
#
#       Close     Volume     Marketcap
# 0  0.753325   674188.0  4.548689e+07
# 1  0.701897   532170.0  4.239957e+07
# 2  0.708448   405283.0  4.281836e+07
# 3  1.067860  1463100.0  6.456929e+07
# 4  1.217440  2150620.0  7.364501e+07

# %%
dogecoin_data.head()
# Out:
#    SNo      Name Symbol                 Date      High       Low      Open  \
# 0    1  Dogecoin   DOGE  2013-12-16 23:59:59  0.000866  0.000150  0.000299
# 1    2  Dogecoin   DOGE  2013-12-17 23:59:59  0.000289  0.000116  0.000207
# 2    3  Dogecoin   DOGE  2013-12-18 23:59:59  0.000362  0.000205  0.000267
# 3    4  Dogecoin   DOGE  2013-12-19 23:59:59  0.001520  0.000328  0.000395
# 4    5  Dogecoin   DOGE  2013-12-20 23:59:59  0.001143  0.000662  0.001143
#
#       Close  Volume     Marketcap
# 0  0.000205     0.0  1.509085e+06
# 1  0.000269     0.0  2.169688e+06
# 2  0.000362     0.0  3.188943e+06
# 3  0.001162     0.0  1.115034e+07
# 4  0.000704     0.0  7.284337e+06

# %% [markdown]
# ## Statistical Summary of datasets

# %%
bitcoin_data.describe()
# Out:
#                SNo          High           Low          Open         Close  \
# count  2991.000000   2991.000000   2991.000000   2991.000000   2991.000000
# mean   1496.000000   6893.326038   6486.009539   6700.146240   6711.290443
# std     863.571653  11642.832456  10869.032130  11288.043736  11298.141921
# min       1.000000     74.561096     65.526001     68.504997     68.431000
# 25%     748.500000    436.179001    422.879486    430.445496    430.569489
# 50%    1496.000000   2387.610107   2178.500000   2269.889893   2286.409912
# 75%    2243.500000   8733.926948   8289.800459   8569.656494   8576.238715
# max    2991.000000  64863.098908  62208.964366  63523.754869  63503.457930
#
#              Volume     Marketcap
# count  2.991000e+03  2.991000e+03
# mean   1.090633e+10  1.208761e+11
# std    1.888895e+10  2.109438e+11
# min    0.000000e+00  7.784112e+08
# 25%    3.036725e+07  6.305579e+09
# 50%    9.460360e+08  3.741503e+10
# 75%    1.592015e+10  1.499957e+11
# ...

# %%
ethereum_data.describe()
# Out:
#                SNo         High          Low         Open        Close  \
# count  2160.000000  2160.000000  2160.000000  2160.000000  2160.000000
# mean   1080.500000   398.258568   365.592589   382.879899   383.910691
# std     623.682612   628.082281   566.611523   599.719862   601.078766
# min       1.000000     0.482988     0.420897     0.431589     0.434829
# 25%     540.750000    14.265225    13.190950    13.757600    13.819200
# 50%    1080.500000   205.124631   193.302715   198.425096   198.643691
# 75%    1620.250000   396.494561   375.146804   386.264935   386.435272
# max    2160.000000  4362.350542  3785.848603  4174.635873  4168.701049
#
#              Volume     Marketcap
# count  2.160000e+03  2.160000e+03
# mean   7.057058e+09  4.172084e+10
# std    1.064526e+10  6.909184e+10
# min    1.021280e+05  3.221363e+07
# 25%    3.825102e+07  1.135576e+09
# 50%    2.148880e+09  2.070063e+10
# 75%    9.629136e+09  4.231010e+10
# max    8.448291e+10  4.828819e+11

# %%
dogecoin_data.describe()
# Out:
#                SNo         High          Low         Open        Close  \
# count  2760.000000  2760.000000  2760.000000  2760.000000  2760.000000
# mean   1380.500000     0.014964     0.012402     0.013669     0.013763
# std     796.887696     0.069103     0.055536     0.062347     0.062559
# min       1.000000     0.000089     0.000085     0.000087     0.000087
# 25%     690.750000     0.000231     0.000222     0.000227     0.000226
# 50%    1380.500000     0.001914     0.001772     0.001849     0.001844
# 75%    2070.250000     0.002986     0.002796     0.002900     0.002899
# max    2760.000000     0.737567     0.608168     0.687801     0.684777
#
#              Volume     Marketcap
# count  2.760000e+03  2.760000e+03
# mean   4.326321e+08  1.760533e+09
# std    2.807320e+09  8.115186e+09
# min    0.000000e+00  1.509085e+06
# 25%    2.536138e+05  2.337892e+07
# 50%    5.582480e+06  2.135789e+08
# 75%    5.098244e+07  3.488812e+08
# max    6.941068e+10  8.868082e+10

# %%
combine_df = pd.DataFrame({'Bitcoin':bitcoin_data['Close'],
                           'Ethereum':ethereum_data['Close'],
                           'Dogecoin':dogecoin_data['Close']})

# %%
combine_df
# Out:
#            Bitcoin  Ethereum  Dogecoin
# 0       144.539993  0.753325  0.000205
# 1       139.000000  0.701897  0.000269
# 2       116.989998  0.708448  0.000362
# 3       105.209999  1.067860  0.001162
# 4        97.750000  1.217440  0.000704
# ...            ...       ...       ...
# 2986  33897.048590       NaN       NaN
# 2987  34668.548402       NaN       NaN
# 2988  35287.779766       NaN       NaN
# 2989  33746.002456       NaN       NaN
# 2990  34235.193451       NaN       NaN
#
# [2991 rows x 3 columns]

# %%
combine_df.describe()
# Out:
#             Bitcoin     Ethereum     Dogecoin
# count   2991.000000  2160.000000  2760.000000
# mean    6711.290443   383.910691     0.013763
# std    11298.141921   601.078766     0.062559
# min       68.431000     0.434829     0.000087
# 25%      430.569489    13.819200     0.000226
# 50%     2286.409912   198.643691     0.001844
# 75%     8576.238715   386.435272     0.002899
# max    63503.457930  4168.701049     0.684777

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.figure(figsize=(13,5))
for col in combine_df.columns.values:
    plt.plot(combine_df[col],label = col)
plt.title("Cryptocurrency Graph")
plt.xlabel('Days')
plt.ylabel('Crypto Price($)')
plt.legend(combine_df.columns.values, loc= 'upper left')
plt.show()

# %%
#Scale the data
#Using min-max scaler method scales the dataset so that all the input features lie between 0 and 100 inclusive
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0,100))
scaled = min_max_scaler.fit_transform(combine_df)
scaled
# Out:
# array([[1.19979445e-01, 7.64097042e-03, 1.71560625e-02],
#        [1.11246111e-01, 6.40717302e-03, 2.64754662e-02],
#        [7.65491881e-02, 6.56433591e-03, 4.00715544e-02],
#        ...,
#        [5.55203497e+01,            nan,            nan],
#        [5.30898670e+01,            nan,            nan],
#        [5.38610356e+01,            nan,            nan]])

# %%
scaled_data = pd.DataFrame(scaled,columns=combine_df.columns)

# %%
#Visualising the Scaled Data
my_crypto = scaled_data
plt.figure(figsize=(13,5))
for col in scaled_data.columns.values:
    plt.plot(my_crypto[col],label = col)
plt.title("Cryptocurrency Scaled Data")
plt.xlabel("Days")
plt.ylabel("Crypto Scaled Price($)")
plt.legend(my_crypto.columns.values,loc = 'upper left')
plt.show()

# %%
DSR = combine_df.pct_change(1)
DSR
# Out:
#        Bitcoin  Ethereum  Dogecoin
# 0          NaN       NaN       NaN
# 1    -0.038328 -0.068268  0.311672
# 2    -0.158345  0.009333  0.346656
# 3    -0.100692  0.507323  2.214575
# 4    -0.070906  0.140075 -0.394519
# ...        ...       ...       ...
# 2986  0.009679  0.000000  0.000000
# 2987  0.022760  0.000000  0.000000
# 2988  0.017861  0.000000  0.000000
# 2989 -0.043692  0.000000  0.000000
# 2990  0.014496  0.000000  0.000000
#
# [2991 rows x 3 columns]

# %%
plt.figure(figsize=(13,5))
for col in DSR.columns.values:
    plt.plot(DSR.index,DSR[col],label=col,alpha= 0.7)
plt.title("Daily Simple Return")
plt.xlabel("Days")
plt.ylabel("Percentage (x 10)")
plt.legend(DSR.columns.values,loc = 'upper right')
plt.show()

# %%
 DSR.std()      #standard deviation
# Out:
# Bitcoin     0.042639
# Ethereum    0.053621
# Dogecoin    0.109000
# dtype: float64

# %%
DSR.mean()
# Out:
# Bitcoin     0.002741
# Ethereum    0.004094
# Dogecoin    0.006110
# dtype: float64

# %%
DSR.corr()   #corelation
# Out:
#            Bitcoin  Ethereum  Dogecoin
# Bitcoin   1.000000 -0.005488 -0.030597
# Ethereum -0.005488  1.000000  0.024557
# Dogecoin -0.030597  0.024557  1.000000

# %%
import seaborn as sns
plt.subplots(figsize = (12,12))
sns.heatmap(DSR.corr(),annot = True,fmt='0.2%')
# Out:
# <AxesSubplot: >

# %%
DCSR = (DSR+1).cumprod()
DCSR
# Out:
#          Bitcoin     Ethereum     Dogecoin
# 0            NaN          NaN          NaN
# 1       0.961672     0.931732     1.311672
# 2       0.809395     0.940428     1.766372
# 3       0.727895     1.417529     5.678134
# 4       0.676283     1.616089     3.438004
# ...          ...          ...          ...
# 2986  234.516744  3085.891871  1145.023290
# 2987  239.854366  3085.891871  1145.023290
# 2988  244.138518  3085.891871  1145.023290
# 2989  233.471731  3085.891871  1145.023290
# 2990  236.856199  3085.891871  1145.023290
#
# [2991 rows x 3 columns]

# %%
plt.figure(figsize=(13,5))
for col in DCSR.columns.values:
    plt.plot(DCSR.index,DCSR[col],lw=2,label=col)
plt.title('Daily Cumulative Simple Return')
plt.xlabel('Days')
plt.ylabel('Growth for $1 investment')
plt.legend(DCSR.columns.values,loc = 'upper left',fontsize = 10)
plt.show()
